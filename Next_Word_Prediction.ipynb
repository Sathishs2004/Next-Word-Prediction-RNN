# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathishs2004/Next-Word-Prediction-RNN/blob/main/Next_Word_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Upload Your Dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a0a97ce-3365-4858-868e-a050f77e509d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a0a97ce-3365-4858-868e-a050f77e509d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Read the .txt File

# %%
with open("ai_ml_next_word_dataset_1000_words.txt", "r", encoding="utf-8") as file:
    text = file.read()

print(text[:1000])
# Out:
# The student analyzes structured data by reducing noise and handling missing values. A neural network predicts customer behavior with consistent feature engineering and balanced datasets. The student understands text sequences for scalable artificial intelligence applications. The dataset improves structured data with consistent feature engineering and balanced datasets. A neural network predicts medical images for scalable artificial intelligence applications. Artificial intelligence understands sensor readings to support reliable decision making in production. The dataset predicts business insights for scalable artificial intelligence applications. The model improves customer behavior while minimizing overfitting with proper validation. The algorithm processes customer behavior before evaluating performance on unseen test data. The algorithm analyzes text sequences while minimizing overfitting with proper validation. Machine learning transforms training samples for scalable artifici
# ...

# %% [markdown]
# ## Import Libraries

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
import numpy as np

# %%
data = text.split("\n")
data = [line.strip() for line in data if line.strip()]

# %% [markdown]
# ## Create Tokenizer

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)

total_words = len(tokenizer.word_index) + 1

print(total_words)
# Out:
# 104

# %% [markdown]
# ## Convert Text into Sequence

# %%
input_sequences = []

for line in data:
    token_list = tokenizer.texts_to_sequences([line])[0]

    for i in range(1, len(token_list)):
        input_sequences.append(token_list[:i+1])

print(len(input_sequences))
# Out:
# 999

# %% [markdown]
# ## Padding

# %%
max_len = max(len(seq) for seq in input_sequences)

input_sequences = pad_sequences(
    input_sequences,
    maxlen=max_len,
    padding="pre"
)

# %% [markdown]
# ## Split Input and Output

# %%
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# %% [markdown]
# ## LSTM Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(total_words, 100),
    tf.keras.layers.LSTM(150),
    tf.keras.layers.Dense(total_words, activation="softmax")
])

# %% [markdown]
# ## Compile Model

# %%
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# ## Train Model

# %%
history = model.fit(
    X,
    y,
    epochs=50,
    batch_size=100
)
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.0621 - loss: 4.6336
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.0701 - loss: 4.5374
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 4s/step - accuracy: 0.0581 - loss: 4.4624
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.0731 - loss: 4.4088
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.0681 - loss: 4.3269
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.1021 - loss: 4.1620
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.1241 - loss: 3.8972
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 0.1652 - loss: 3.5329
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.2503 - loss: 3.1310
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.3143 - loss: 2.7787
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.4474 - loss: 2.4871
# Epoch 12/50
# ...

# %% [markdown]
# ## Predict next word using Python

# %%
seed_text = "the student analyzes structured data by "

token_list = tokenizer.texts_to_sequences([seed_text])[0]
token_list = pad_sequences([token_list], maxlen=max_len-1, padding="pre")

prediction = model.predict(token_list, verbose=0)
predicted_index = np.argmax(prediction, axis=-1)[0]

for word, index in tokenizer.word_index.items():
    if index == predicted_index:
        print("Predicted Word:", word)
        break
